# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.yaml") # 학습 전의 yolo 모델 구조만 가져오기
# model = YOLO("yolov8n.pt") # coco 데이터셋으로 사전학습한 모델 가져오기
# model = YOLO("~/yolo11/myproject/train/weights/best.pt") # 내 모델 가져오기

# %%
# Train the model
results = model.train(data="/home/ubuntu/yolov3/mydata_2/mydata.yaml", epochs=300, imgsz=640, project="myproject")
# Out:
# Ultralytics 8.4.48 🚀 Python-3.12.3 torch-2.11.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 11865MiB)
# ...

# %%
# 추론하기 - 비디오
results = model.predict("~/yolo11/data/video/material_B_60s.avi", show=True, save=Tr
ue, imgsz=640, conf=0.5, save_conf=True, project="~/yolo11/myproject")

# %%
# Segmentation 맛보기
yolo segment predict model=yolo11n-seg.pt source=0 show=True save_txt=True

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov11n-seg.pt") # load an official model

# Predict with the model
results = model(source="https://youtu.be/LNwODJXcvt4", show=True)

# %%
# Pose Estimation
yolo pose predict model=yolov8n-pose.pt source="https://youtu.be/LNwODJXcvt4" show=T
rue save_txt=True

# %%
# Tracking
# 트래킹 아이디는 label.txt 파일에서 맨 마지막
yolo track model=yolov8n.pt source="https://youtu.be/LNwODJXcvt4" show=True save_txt=True
